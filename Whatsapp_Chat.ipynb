# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:yellow;
#            font-size:400%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="
#           padding: 20px;
#           color:black;
#           font-size:120%;
#           font-weight:bold;
#           line-height:1.5;
#           text-align:center;">
# WHAT'S APP CHAT EXPLORATORY DATA ANALYSIS
# </p>
# </div>

# %% [markdown]
# WhatsApp is one of the most used messenger applications today with more than 2 Billion users worldwide. It was found that more than 65 billion messages are sent on WhatsApp daily so we can use WhatsApp chats for analyzing our chat with a friend, customer, or a group of people.
# Before starting with the task of WhatsApp Chat analysis with Python you need to extract your WhatsApp data from your smartphone which is a very easy task. To extract your WhatsApp chats, just open any chat with a person or a group and follow the steps mentioned below:
# * If you are having an iPhone then tap on the Contact Name or the Group Name. In case you are having an Android smartphone then tap on the 3 dots above.
# * Then scroll to the bottom and top on Export Chat.
# * Then select without media for simplicity if it asks you whether you want your chats with or without media.
# * Then email this chat to yourself and download it to your system.
#
# So this is how you can easily get your WhatsApp chats with any person or a group for the task of WhatsApp chat analysis. In the section below, I will take you through WhatsApp chat analysis with Python.

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:200%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 20px;"> Importing Libraries</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
f=open("C:\\Users\\Avishekh Kumar Gupta\\Downloads\\Chat.txt",encoding="utf-8")
## reading the file

# %%
pd.read_table("C:\\Users\\Avishekh Kumar Gupta\\Downloads\\Chat.txt")
# Out:
#      7/5/20, 00:03 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 0     6/5/18, 10:27 - Avishekh created group "🎉Happy...
# 1                        6/5/18, 10:27 - You were added
# 2       7/21/20, 06:01 - Ritesh Bhaiya: <Media omitted>
# 3     7/21/20, 06:01 - Ritesh Bhaiya: *100 साल पहले ...
# 4                *ये तस्वीरें लगभग 101 साल पुरानी हैं,*
# ...                                                 ...
# 1256  12/18/23, 19:45 - Your security code with Avis...
# 1257          1/1/24, 04:54 - Papa Jio: <Media omitted>
# 1258          1/1/24, 04:54 - Papa Jio: <Media omitted>
# 1259          1/1/24, 04:54 - Papa Jio: <Media omitted>
# 1260      1/1/24, 09:16 - Deepak Anpar: <Media omitted>
#
# [1261 rows x 1 columns]

# %% [markdown]
# # Read the chat

# %%
data=f.read()
print(data)
# Out:
# 7/5/20, 00:03 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 6/5/18, 10:27 - Avishekh created group "🎉Happy Gupta Family😃😃😃"
# 6/5/18, 10:27 - You were added
# 7/21/20, 06:01 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:01 - Ritesh Bhaiya: *100 साल पहले हुए इस लॉकडाउन को देखिए,*
# *ये तस्वीरें लगभग 101 साल पुरानी हैं,*
# *1918 से 2020 तक के इतिहास ने वापसी की है।*
# ये कुछ तस्वीरें हैंl
# 7/21/20, 06:01 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/21/20, 06:02 - Ritesh Bhaiya: <Media omitted>
# 7/25/20, 07:28 - Mantu Bhaiya P: <Media omitted>
# 7/25/20, 07:28 - Mantu Bhaiya P: <Media omitted>
# 7/25/20, 07:57 - +91 99773 85858: <Media omitted>
# ...

# %% [markdown]
# # Checking the type of Data

# %%
type(data)
# Out:
# str

# %%
# l=data.split("-")
# l

# %%
# l[0::2]

# %%
pattern="\d{1,2}/\d{1,2}/\d{2},\s\d{2}:\d{2}\s-\s"

# %%
messages=re.split(pattern,data)
messages
# Out:
# ['',
#  'Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Avishekh created group "🎉Happy Gupta Family😃😃😃"\n',
#  'You were added\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: *100 साल पहले हुए इस लॉकडाउन को देखिए,*\n*ये तस्वीरें लगभग 101 साल पुरानी हैं,*\n*1918 से 2020 तक के इतिहास ने वापसी की है।*\nये कुछ तस्वीरें हैंl\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Ritesh Bhaiya: <Media omitted>\n',
#  'Mantu Bhaiya P: <Media omitted>\n',
#  'Mantu Bhaiya P: <Media omitted>\n',
#  '+91 99773 85858: <Media omitted>\n',
#  '+91 99773 85858: <Media omitted>\n',
#  'Kumari Di: <Media omitted>\n',
#  'Kumari Di: <Media omitted>\n',
#  '+91 99773 85858: Kis ka hai\n',
# ...

# %%
messages=messages[1:]
#messages

# %%
len(messages)
# Out:
# 846

# %% [markdown]
# type(dates)
# len(dates)

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['7/5/20, 00:03 - ',
#  '6/5/18, 10:27 - ',
#  '6/5/18, 10:27 - ',
#  '7/21/20, 06:01 - ',
#  '7/21/20, 06:01 - ',
#  '7/21/20, 06:01 - ',
#  '7/21/20, 06:02 - ',
#  '7/21/20, 06:02 - ',
#  '7/21/20, 06:02 - ',
#  '7/21/20, 06:02 - ',
#  '7/21/20, 06:02 - ',
#  '7/21/20, 06:02 - ',
#  '7/25/20, 07:28 - ',
#  '7/25/20, 07:28 - ',
#  '7/25/20, 07:57 - ',
#  '7/25/20, 07:57 - ',
#  '8/1/20, 09:43 - ',
#  '8/1/20, 09:44 - ',
#  '8/1/20, 10:02 - ',
#  '8/1/20, 10:12 - ',
#  '8/1/20, 10:16 - ',
#  '8/1/20, 11:37 - ',
#  '8/1/20, 11:37 - ',
#  '8/1/20, 11:37 - ',
#  '8/1/20, 11:37 - ',
#  '8/1/20, 11:37 - ',
#  '8/1/20, 18:09 - ',
#  '8/3/20, 07:28 - ',
#  '8/3/20, 07:55 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/5/20, 19:09 - ',
#  '8/9/20, 15:13 - ',
#  '8/9/20, 19:41 - ',
#  '8/9/20, 19:42 - ',
#  '8/9/20, 19:43 - ',
#  '8/9/20, 19:44 - ',
# ...

# %%
df=pd.DataFrame({"user_message":messages,"message_date":dates})
df
# Out:
#                                           user_message        message_date
# 0    Messages and calls are end-to-end encrypted. N...    7/5/20, 00:03 -
# 1    Avishekh created group "🎉Happy Gupta Family😃😃😃"\n    6/5/18, 10:27 -
# 2                                     You were added\n    6/5/18, 10:27 -
# 3                     Ritesh Bhaiya: <Media omitted>\n   7/21/20, 06:01 -
# 4    Ritesh Bhaiya: *100 साल पहले हुए इस लॉकडाउन को...   7/21/20, 06:01 -
# ..                                                 ...                 ...
# 841  Your security code with Avishekh changed. Tap ...  12/18/23, 19:45 -
# 842                        Papa Jio: <Media omitted>\n    1/1/24, 04:54 -
# 843                        Papa Jio: <Media omitted>\n    1/1/24, 04:54 -
# 844                        Papa Jio: <Media omitted>\n    1/1/24, 04:54 -
# 845                  Deepak Anpar: <Media omitted>\n\n    1/1/24, 09:16 -
#
# [846 rows x 2 columns]

# %% [markdown]
# # What is the shape of chat

# %%
df.shape
# Out:
# (846, 2)

# %% [markdown]
# ## This group chat has 846 messages

# %% [markdown]
# ## Checking dtypes

# %%
df.dtypes
# Out:
# user_message    object
# message_date    object
# dtype: object

# %%
df.dtypes.to_frame().T
# Out:
#   user_message message_date
# 0       object       object

# %% [markdown]
# # Since message_date is object so convert it into datetime

# %%
df.sample(10)
# Out:
#                                           user_message        message_date
# 633                        Papa Jio: <Media omitted>\n   8/15/21, 12:11 -
# 493                        Papa Jio: <Media omitted>\n   5/14/21, 07:17 -
# 23                    Ritesh Bhaiya: <Media omitted>\n    8/1/20, 11:37 -
# 618                        Papa Jio: <Media omitted>\n   7/30/21, 08:15 -
# 149  Aminesh ❤️❤️❤️❤️👍😎: https://fb.watch/1nKzWYiVf...  10/27/20, 16:42 -
# 757                  Sandeep Hydera: <Media omitted>\n   4/28/22, 03:32 -
# 572                        Papa Jio: <Media omitted>\n    7/1/21, 06:40 -
# 773                    Deepak Anpar: <Media omitted>\n   9/15/22, 22:36 -
# 99   Ritesh Bhaiya: *1अक्टूबर से खुली मिठाइयों पर भ...   9/28/20, 12:38 -
# 596                        Papa Jio: <Media omitted>\n   7/18/21, 07:07 -

# %%
#df["message_date"]=pd.to_datetime(df["message_date"],format='%m/%d/%y, %H:%M%p - ')

# %%
df["message_date"]=pd.to_datetime(df["message_date"],format='%m/%d/%y, %H:%M - ')  #%p for am,pm

# %%
df.dtypes
# Out:
# user_message            object
# message_date    datetime64[ns]
# dtype: object

# %%
df["message_date"]
# Out:
# 0     2020-07-05 00:03:00
# 1     2018-06-05 10:27:00
# 2     2018-06-05 10:27:00
# 3     2020-07-21 06:01:00
# 4     2020-07-21 06:01:00
#               ...
# 841   2023-12-18 19:45:00
# 842   2024-01-01 04:54:00
# 843   2024-01-01 04:54:00
# 844   2024-01-01 04:54:00
# 845   2024-01-01 09:16:00
# Name: message_date, Length: 846, dtype: datetime64[ns]

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:200%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 20px;"> Feature Engineering</p>

# %%
df["year"]=df["message_date"].dt.year
df["month"]=df["message_date"].dt.month_name()
df["day"]=df["message_date"].dt.day
df["hour"]=df["message_date"].dt.hour
df["month"]=df["message_date"].dt.month
df["day_name"]=df["message_date"].dt.day_name()
df["Date"]=df["message_date"].dt.date
df["minute"]=df["message_date"].dt.minute
df.sample(6)
# Out:
#            message_date  year  month  day  hour   day_name        Date  \
# 832 2023-09-04 10:43:00  2023      9    4    10     Monday  2023-09-04
# 391 2021-03-10 05:50:00  2021      3   10     5  Wednesday  2021-03-10
# 733 2022-01-01 00:08:00  2022      1    1     0   Saturday  2022-01-01
# 421 2021-04-12 11:14:00  2021      4   12    11     Monday  2021-04-12
# 366 2021-02-17 10:20:00  2021      2   17    10  Wednesday  2021-02-17
# 610 2021-07-26 08:57:00  2021      7   26     8     Monday  2021-07-26
#
#      minute       user_name             message
# 832      43        Papa Jio   <Media omitted>\n
# 391      50        Papa Jio   <Media omitted>\n
# 733       8   Ritesh Bhaiya   <Media omitted>\n
# 421      14  Monu Pathanpur   <Media omitted>\n
# 366      20   Ritesh Bhaiya   <Media omitted>\n
# 610      57        Papa Jio   <Media omitted>\n

# %%
users_1=[]
messages_1=[]
for i in df["user_message"]:
    if (("created group" in i) | ("changed the group" in i)):
        li=[]
        li.append(i)
        #print(li)
    elif (("created group" not in i) | ("changed the group" not in i)) :
        if ":" in i:
            li=i.split(":",maxsplit=1)
            #print(li)
        else:
            li=[]
            li.append(i)
    if len(li)>1: 
        users_1.append(li[0])
        messages_1.append(li[1])
    else:
        users_1.append("group_notification")
        messages_1.append(li[0])

# %% [markdown]
# ## Here we verify the lenght of Users & Messages

# %%
print(len(users_1))
print(len(messages_1))
# Out:
# 846
# 846

# %%
df["user_name"]=users_1
df["message"]=messages_1
df.sample(10)
# Out:
#                                           user_message        message_date  \
# 79                    Ritesh Bhaiya: <Media omitted>\n 2020-08-26 07:01:00
# 701              Aminesh ❤️❤️❤️❤️👍😎: <Media omitted>\n 2021-10-06 06:43:00
# 688                        Papa Jio: <Media omitted>\n 2021-09-23 05:25:00
# 712         Mantu Bhaiya P: This message was deleted\n 2021-11-04 07:35:00
# 683                        Papa Jio: <Media omitted>\n 2021-09-20 04:36:00
# 49               Aminesh ❤️❤️❤️❤️👍😎: <Media omitted>\n 2020-08-17 14:18:00
# 272                    Deepak Anpar: <Media omitted>\n 2021-01-10 21:51:00
# 392  Papa Jio: ASHOK KUMAR  GUPTA  Lucknow ** ने आप... 2021-03-11 06:00:00
# 562                        Papa Jio: <Media omitted>\n 2021-06-26 08:03:00
# 631  Avishekh: https://www.youtube.com/watch?v=RftQ... 2021-08-15 11:39:00
#
#      year  month  day  hour   day_name        Date  minute  \
# 79   2020      8   26     7  Wednesday  2020-08-26       1
# ...

# %%
df.drop(columns=["user_message"],inplace=True)

# %%
df.head()
# Out:
#          message_date  year  month  day  hour day_name        Date  minute  \
# 0 2020-07-05 00:03:00  2020      7    5     0   Sunday  2020-07-05       3
# 1 2018-06-05 10:27:00  2018      6    5    10  Tuesday  2018-06-05      27
# 2 2018-06-05 10:27:00  2018      6    5    10  Tuesday  2018-06-05      27
# 3 2020-07-21 06:01:00  2020      7   21     6  Tuesday  2020-07-21       1
# 4 2020-07-21 06:01:00  2020      7   21     6  Tuesday  2020-07-21       1
#
#             user_name                                            message
# 0  group_notification  Messages and calls are end-to-end encrypted. N...
# 1  group_notification  Avishekh created group "🎉Happy Gupta Family😃😃😃"\n
# 2  group_notification                                   You were added\n
# 3       Ritesh Bhaiya                                  <Media omitted>\n
# 4       Ritesh Bhaiya   *100 साल पहले हुए इस लॉकडाउन को देखिए,*\n*ये ...

# %% [markdown]
# # How big is my Chatting

# %%
df.shape[0]
# Out:
# 846

# %% [markdown]
# # How big is the chating messsages

# %%
len(df[df["user_name"]!="group_notification"])
# Out:
# 800

# %% [markdown]
# # How many is the Notification Messages

# %%
len(df[df["user_name"]=="group_notification"])
# Out:
# 46

# %% [markdown]
# # Who is Active User

# %%
u=df[df["user_name"]!="group_notification"]
sns.countplot(x="user_name",data=u)
plt.xlabel("user_name",fontsize=15, loc="center",fontweight="bold")
plt.ylabel("count",fontsize=15, loc="center",fontweight="bold")
plt.title("Most Active User ",color="red",fontweight="bold",fontsize=20)
plt.xticks(rotation=90);
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128135 (\N{HAIRCUT}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127969 (\N{HOUSE WITH GARDEN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 128135 (\N{HAIRCUT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # Top 3 Most Active Users

# %%
u["user_name"].value_counts().head(3)
# Out:
# Papa Jio         346
# Ritesh Bhaiya     83
# Avishekh          59
# Name: user_name, dtype: int64

# %% [markdown]
# # Bottom 3 Active Users

# %%
u["user_name"].value_counts().tail(3)
# Out:
# Home🏡❤️❤️❤️❤️      1
# +91 99112 06119    1
# +91 78007 70461    1
# Name: user_name, dtype: int64

# %%
plt.figure(figsize=(14,4),facecolor="pink")
plt.subplot(1,2,1)
sns.barplot(x=u["user_name"].value_counts().head(3).index,y=u["user_name"].value_counts().head(3).values,palette="bright")
plt.title("Top 3 Active users ",fontsize=20,color="Red",fontweight="bold")
plt.subplot(1,2,2)
sns.barplot(x=u["user_name"].value_counts().tail(3).index,y=u["user_name"].value_counts().tail(3).values,palette="bright")
plt.title("Bottom 3 Active users ",color="Red",fontsize=20,fontweight="bold");
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127969 (\N{HOUSE WITH GARDEN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 127969 (\N{HOUSE WITH GARDEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Total words in the Chat

# %%
t_words=[]
for m in u["message"]:
    words=m.split()
    t_words.extend(words)
print(t_words)
# Out:
# ['<Media', 'omitted>', '*100', 'साल', 'पहले', 'हुए', 'इस', 'लॉकडाउन', 'को', 'देखिए,*', '*ये', 'तस्वीरें', 'लगभग', '101', 'साल', 'पुरानी', 'हैं,*', '*1918', 'से', '2020', 'तक', 'के', 'इतिहास', 'ने', 'वापसी', 'की', 'है।*', 'ये', 'कुछ', 'तस्वीरें', 'हैंl', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', 'Kis', 'ka', 'hai', 'Kiska', 'hua', 'Saroj', 'ka', 'ladka', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', 'देखो', '*Vimlesh', 'Kumar', 'Gupta*', 'ने', 'आपके', 'लिए', 'क्या', 'भेजा', 'है!', '*ब्लू', 'लाइन', 'पर', 'टच', 'करें', 'और', 'देखें!*👇👇', 'wow-club.xyz/hd/?u=Vimlesh_Kumar_Gupta', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>
# ...

# %%
chat=list(map(lambda x: x.replace("\n",""),u["message"].values))

# %%
t_words=[]
for m in chat:
    words=m.split()
    t_words.extend(words)
print(t_words)
# Out:
# ['<Media', 'omitted>', '*100', 'साल', 'पहले', 'हुए', 'इस', 'लॉकडाउन', 'को', 'देखिए,**ये', 'तस्वीरें', 'लगभग', '101', 'साल', 'पुरानी', 'हैं,**1918', 'से', '2020', 'तक', 'के', 'इतिहास', 'ने', 'वापसी', 'की', 'है।*ये', 'कुछ', 'तस्वीरें', 'हैंl', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', 'Kis', 'ka', 'hai', 'Kiska', 'hua', 'Saroj', 'ka', 'ladka', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', 'देखो', '*Vimlesh', 'Kumar', 'Gupta*', 'ने', 'आपके', 'लिए', 'क्या', 'भेजा', 'है!', '*ब्लू', 'लाइन', 'पर', 'टच', 'करें', 'और', 'देखें!*👇👇', 'wow-club.xyz/hd/?u=Vimlesh_Kumar_Gupta', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media', 'omitted>', '<Media',
# ...

# %%
t_words=[]
for m in chat:
    words=m.split()
    t_words.extend(words)
print(len(t_words))
# Out:
# 5929

# %%
u.columns
# Out:
# Index(['message_date', 'year', 'month', 'day', 'hour', 'day_name', 'Date',
#        'minute', 'user_name', 'message'],
#       dtype='object')

# %% [markdown]
# # How many Medias shared in chat

# %%
u[u["message"]==" <Media omitted>\n"]
# Out:
#            message_date  year  month  day  hour   day_name        Date  \
# 3   2020-07-21 06:01:00  2020      7   21     6    Tuesday  2020-07-21
# 5   2020-07-21 06:01:00  2020      7   21     6    Tuesday  2020-07-21
# 6   2020-07-21 06:02:00  2020      7   21     6    Tuesday  2020-07-21
# 7   2020-07-21 06:02:00  2020      7   21     6    Tuesday  2020-07-21
# 8   2020-07-21 06:02:00  2020      7   21     6    Tuesday  2020-07-21
# ..                  ...   ...    ...  ...   ...        ...         ...
# 838 2023-11-01 22:02:00  2023     11    1    22  Wednesday  2023-11-01
# 839 2023-11-01 22:02:00  2023     11    1    22  Wednesday  2023-11-01
# 842 2024-01-01 04:54:00  2024      1    1     4     Monday  2024-01-01
# 843 2024-01-01 04:54:00  2024      1    1     4     Monday  2024-01-01
# 844 2024-01-01 04:54:00  2024      1    1     4     Monday  2024-01-01
#
#      minute      user_name             message
# 3         1  Ritesh Bhaiya   <Media omitted>\n
# ...

# %%
len(u[u["message"]==" <Media omitted>\n"])
# Out:
# 684

# %% [markdown]
# # We have import one Library urlextract to extract the URL's present in the chat

# %%
##!pip install urlextract

# %%
from urlextract import URLExtract

# %%
count=0
extractor=URLExtract()
for i in u["message"]:
    if len(extractor.find_urls(i))==1:
        count=count+1
print(count)
# Out:
# 46

# %% [markdown]
# ### There are 46 URL's present in whole chat

# %% [markdown]
# # Since total words in my chat are 5929 but it includes media and URL's so we filter out the words exclusively out of urls and medias

# %% [markdown]
# # Messages without Medias

# %%
u_m=u[u["message"]!=" <Media omitted>\n"]
u_m
# Out:
#            message_date  year  month  day  hour  day_name        Date  minute  \
# 4   2020-07-21 06:01:00  2020      7   21     6   Tuesday  2020-07-21       1
# 18  2020-08-01 10:02:00  2020      8    1    10  Saturday  2020-08-01       2
# 19  2020-08-01 10:12:00  2020      8    1    10  Saturday  2020-08-01      12
# 20  2020-08-01 10:16:00  2020      8    1    10  Saturday  2020-08-01      16
# 26  2020-08-01 18:09:00  2020      8    1    18  Saturday  2020-08-01       9
# ..                  ...   ...    ...  ...   ...       ...         ...     ...
# 775 2022-09-16 08:00:00  2022      9   16     8    Friday  2022-09-16       0
# 802 2023-01-01 16:10:00  2023      1    1    16    Sunday  2023-01-01      10
# 811 2023-03-10 08:05:00  2023      3   10     8    Friday  2023-03-10       5
# 833 2023-09-09 09:40:00  2023      9    9     9  Saturday  2023-09-09      40
# 845 2024-01-01 09:16:00  2024      1    1     9    Monday  2024-01-01      16
#
# ...

# %%
print(len(u_m[u["message"] != " <Media omitted>\n"]))
# Out:
# 116
# <ipython-input-46-62ecb3a3262e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(u_m[u["message"] != " <Media omitted>\n"]))

# %%
#pip install urlextract

# %% [markdown]
# ## Count the words without URL's links

# %%
extractor=URLExtract()
t_words=[]
for i in u_m["message"]:
    #print(i)
    if len(extractor.find_urls(i))==0:
        words=i.split()
        t_words.extend(words)
print(len(t_words))
# Out:
# 3973

# %%
### Top 5 and least 5 ACTIVE and not active CHATTING WORD

# %%
from collections import Counter

# %%
d=Counter(t_words)
d
# Out:
# Counter({'*100': 1,
#          'साल': 4,
#          'पहले': 3,
#          'हुए': 2,
#          'इस': 6,
#          'लॉकडाउन': 1,
#          'को': 46,
#          'देखिए,*': 1,
#          '*ये': 3,
#          'तस्वीरें': 2,
#          'लगभग': 1,
#          '101': 1,
#          'पुरानी': 1,
#          'हैं,*': 1,
#          '*1918': 1,
#          'से': 45,
#          '2020': 1,
#          'तक': 5,
#          'के': 69,
#          'इतिहास': 1,
#          'ने': 9,
#          'वापसी': 1,
#          'की': 49,
#          'है।*': 9,
#          'ये': 7,
#          'कुछ': 8,
#          'हैंl': 1,
#          'Kis': 1,
#          'ka': 3,
#          'hai': 1,
#          'Kiska': 1,
#          'hua': 1,
#          'Saroj': 1,
#          'ladka': 1,
#          'My': 1,
#          'no': 2,
#          'is': 6,
#          '8853386818': 1,
#          'added': 1,
#          '.': 2,
#          'So': 4,
#          'curt': 1,
#          'babu': 2,
#          'Rakhi': 1,
#          'pic': 1,
# ...

# %%
d=Counter(t_words)
sorted(d.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('के', 69),
#  ('की', 49),
#  ('में', 47),
#  ('को', 46),
#  ('से', 45),
#  ('है', 43),
#  ('और', 39),
#  ('बनिये', 37),
#  (',', 36),
#  (':', 34),
#  ('का', 33),
#  ('तो', 30),
#  ('भी', 28),
#  ('लाख', 28),
#  ('कर', 27),
#  ('।', 24),
#  ('या', 20),
#  ('to', 16),
#  ('नहीं', 15),
#  ('पर', 15),
#  ('the', 15),
#  ('हैं', 14),
#  ('है।', 13),
#  ('this', 13),
#  ('जो', 12),
#  ('आप', 12),
#  ('ही', 12),
#  ('बार', 12),
#  ('हो', 11),
#  ('यह', 11),
#  ('आपको', 11),
#  ('करने', 11),
#  ('वाले', 11),
#  ('दूध', 11),
#  ('एक', 10),
#  ('सभी', 10),
#  ('लिए', 10),
#  ('you', 10),
#  ('वाला', 10),
#  ('नही', 10),
#  ('भैंस', 10),
#  ('गाय', 10),
#  ('ने', 9),
#  ('है।*', 9),
#  ('परिवार', 9),
#  ('for', 9),
#  ('कुछ', 8),
#  ('होता', 8),
#  ('।।', 8),
#  ('all', 8),
#  ('बहुत', 8),
#  ('।*', 8),
#  ('न', 8),
#  ('ज्यादा', 8),
#  ('virus', 8),
#  ('a', 8),
#  ('समझ', 8),
#  ('लड़के', 8),
#  ('बच्चे', 8),
#  ('ये', 7),
#  ('अपनी', 7),
#  ('कि', 7),
#  ('वह', 7),
#  ('है,', 7),
# ...

# %% [markdown]
# # Top Most chatting words

# %%
sorted(d.items(),key=lambda x:x[1],reverse=True)[0:4]
# Out:
# [('के', 69), ('की', 49), ('में', 47), ('को', 46)]

# %% [markdown]
# # Least Chatting words

# %%
sorted(d.items(),key=lambda x:x[1])[:4]
# Out:
# [('*100', 1), ('लॉकडाउन', 1), ('देखिए,*', 1), ('लगभग', 1)]

# %%
##!pip install -->upgrade worldcloud
# Out:
# ERROR: Could not find a version that satisfies the requirement worldcloud (from versions: none)
# ERROR: No matching distribution found for worldcloud

# %%
##from wordcloud import WordCloud

# %%
text=" ".join(t_words)
text
# Out:
# '*100 साल पहले हुए इस लॉकडाउन को देखिए,* *ये तस्वीरें लगभग 101 साल पुरानी हैं,* *1918 से 2020 तक के इतिहास ने वापसी की है।* ये कुछ तस्वीरें हैंl Kis ka hai Kiska hua Saroj ka ladka My no is 8853386818 added . So curt babu Rakhi ka pic *कोई भी मनुष्य किस बात को,* *किस प्रकार से समझता है।* *यह उसकी मानसिकता तय करती है।* *कोई दूसरों की थाली में से भी,* *छीन कर खाने में अपनी शान समझता है।* *तो कोई अपनी थाली में से दूसरों को,* *निवाले खिला कर संतुष्ट होता है।* *सारा खेल संस्कारों, समझ,* *और मानसिकता का है।* *लेकिन एक बात तो तयशुदा है कि छीन कर,* *खाने वालों का कभी पेट नहीं भरता।* *और बाँट कर खाने वाले,* *कभी भी भूखे नहीं रहते।* 🐚🌼🐚 🐾 *स्नेह वंदन* 🐾 Mere pyara bhanja singar ho gya ji Supre Wonder full singar Raj ranu madul 🔥 bahut khub👍🔥🔥 7800770461no group se hta do Bhai Hello everyone Heero kha ja rha h 👌👌 💥आप सभी 💜💜💜💜💜💜को दिवाली की हार्दिक सुभकामनाये 💥 ॥ 💫 ॐ महलक्ष्म्यै नमः 💫॥ दीयों की रौशनी से झिलमिलाता आँगन हो , पटाख़ों की गूँजो से आसमान रोशन हो , ऐसे आये झूम के यह दिवाली , हर तरफ खुशि
# ...

# %% [markdown]
# font_path = "C://Windows//Fonts//Arial.ttf"
# wordcloud = WordCloud(width=800, height=800, background_color='black', font_path=font_path).generate(text)
# plt.figure(figsize=(15,15), facecolor=None)
# plt.imshow(wordcloud)
# plt.tight_layout(pad=0)
# plt.show()

# %% [markdown]
# # Which was the most chatting month

# %%
sns.countplot(df["month"]);
plt.xticks(rotation=90)
plt.title("Most Chatting Month",fontweight="bold",fontsize=20);
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Most active day

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["day_name"],data=df,palette="pastel");
plt.xticks(rotation=90,)
plt.title("Most Active Day",fontweight="bold",fontsize=20);
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Most Chatting Day wrt User Name

# %%
plt.figure(figsize=(15,5))
sns.countplot(u["user_name"],hue="day_name",data=df,palette="muted");
plt.xticks(rotation=90);
plt.title("Most Chatting Day Per Users",fontweight="bold",fontsize=20);
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128135 (\N{HAIRCUT}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127969 (\N{HOUSE WITH GARDEN}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# # Most active year

# %%
sns.countplot(df["year"]);
plt.xticks(rotation=90);
plt.title("Most Active Year",fontweight="bold",fontsize=20);
# Out:
# C:\Users\Avishekh Kumar Gupta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Busy month of each year

# %%
plt.figure(figsize=(20,12))
sns.countplot(x="year",hue="month",data=df,palette="bright")
plt.title("Most Busy Month of each year",fontweight="bold",fontsize=20);

# %% [markdown]
# # Messages Trend over the years

# %%
date=df.groupby(["Date"])["message"].count().reset_index()
date
# Out:
#            Date  message
# 0    2018-06-05        2
# 1    2020-07-05        1
# 2    2020-07-21        9
# 3    2020-07-25        4
# 4    2020-08-01       11
# ..          ...      ...
# 308  2023-09-04        1
# 309  2023-09-09        1
# 310  2023-11-01        7
# 311  2023-12-18        1
# 312  2024-01-01        4
#
# [313 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(date["Date"],date["message"])
plt.xlabel("Year",fontsize=10, loc="center")
plt.title("Messages Trend over the years",fontweight="bold",fontsize=20);

# %% [markdown]
# ## Timeline Report of each user

# %%
for i in u["user_name"].unique():
    print(i)
user=input("kindly pick the user for which u want to see his/her activeness with respect to day,month and year")
user_df=df[df["user_name"]==user]
timeline=["day_name","month","year"]
pos=1
plt.figure(figsize=(15,10))
for i in timeline:
    plt.subplot(1,3,pos)
    sns.countplot(x=i,data=user_df)
    plt.xticks(rotation=90)
    plt.xlabel(i)
    pos=pos+1
plt.suptitle("Timeline Report of each user", fontweight="bold", fontsize=20)
# Out:
# Ritesh Bhaiya
# Mantu Bhaiya P
# +91 99773 85858
# Kumari Di
# Deepak Anpar
# +91 78007 70461
# Aminesh ❤️❤️❤️❤️👍😎
# Avishekh
# Anu Anshu💇💇
# Monu Pathanpur
# Papa Jio
# Home🏡❤️❤️❤️❤️
# Jija Gazipur
# +91 99112 06119
# Sudeep
# Sandeep Hydera
# Mantu Bhaiya
# kindly pick the user for which u want to see his/her activeness with respect to day,month and yearPapa Jio
# Text(0.5, 0.98, 'Timeline Report of each user')

# %% [markdown]
# ## Timeline Report of each user of year 2023

# %%
x=u[u["year"]==2023]

# %%
for i in x["user_name"].unique():
    print(i)
user=input("Kindly pick the user for which u want to see his/her activeness with respect to day,month and year ")
user_df=x[x["user_name"]==user]
x1=user_df.groupby(["Date"])["message"].count().reset_index()
plt.plot(x1["Date"],x1["message"])
plt.xticks(rotation=90,)
plt.xlabel("Date",fontsize=10, loc="center")
plt.title("Timeline Report of each user of year 2023 wrt Date", fontsize=20,fontweight="bold");
# Out:
# Papa Jio
# Aminesh ❤️❤️❤️❤️👍😎
# Jija Gazipur
# Mantu Bhaiya
# Deepak Anpar
# Kindly pick the user for which u want to see his/her activeness with respect to day,month and year Papa Jio

# %%
for i in x["user_name"].unique():
    print(i)
user=input("kindly pick the user for which u want to see his/her activeness with respect to day,month and year")
user_df=x[x["user_name"]==user]
x1=user_df.groupby(["month"])["message"].count().reset_index()
plt.plot(x1["month"],x1["message"])
plt.xticks(rotation=90)
plt.xlabel("Month Number",fontsize=10, loc="center")
plt.title("Timeline Report of each user of year 2023 wrt Months", fontsize=20,fontweight="bold");
# Out:
# Papa Jio
# Aminesh ❤️❤️❤️❤️👍😎
# Jija Gazipur
# Mantu Bhaiya
# Deepak Anpar
# kindly pick the user for which u want to see his/her activeness with respect to day,month and yearPapa Jio
